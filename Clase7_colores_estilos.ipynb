# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
x = np.linspace(0,5,11)

# %% [markdown]
# ### Style

# %%
print(plt.style.available) #Ver estilos disponibles
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# plt.style.use('estilo')
#
# | Estilo                  | Uso                                                                                      |
# |-------------------------|------------------------------------------------------------------------------------------|
# | `'Solarize_Light2'`      | Un estilo claro y agradable para la lectura.                                            |
# | `'_classic_test_patch'` | Estilo de prueba.                                                                       |
# | `'_mpl-gallery'`         | Estilo de la galería de matplotlib.                                                     |
# | `'bmh'`                  | Basado en la biblioteca de gráficos Bayesian Methods for Hackers.                        |
# | `'classic'`              | Estilo clásico de Matplotlib.                                                           |
# | `'dark_background'`      | Fondo oscuro con líneas claras, útil para presentaciones.                                |
# | `'fast'`                 | Estilo rápido, adecuado para visualización interactiva.                                   |
# | `'fivethirtyeight'`      | Estilo que imita el aspecto de gráficos de FiveThirtyEight.                              |
# | `'ggplot'`               | Estilo similar a los gráficos en el sistema R ggplot.                                    |
# | `'grayscale'`            | Gráficos en escala de grises.                                                            |
# | `'seaborn-v0_8'`         | Estilo de Seaborn versión 0.8.                                                           |
# | `'seaborn-v0_8-bright'`  | Variante brillante del estilo Seaborn.                                                   |
# | `'seaborn-v0_8-colorblind'`| Variante para personas con discapacidad visual en el estilo Seaborn.                    |
# | `'seaborn-v0_8-dark'`    | Variante oscura del estilo Seaborn.                                                      |
# | `'seaborn-v0_8-darkgrid'`| Variante oscura con líneas de cuadrícula del estilo Seaborn.                            |
# | `'seaborn-v0_8-deep'`    | Variante más profunda del estilo Seaborn.                                                |
# | `'seaborn-v0_8-muted'`   | Variante atenuada del estilo Seaborn.                                                    |
# | `'seaborn-v0_8-notebook'`| Estilo Seaborn diseñado para notebooks.                                                 |
# | `'seaborn-v0_8-paper'`   | Estilo Seaborn diseñado para impresión en papel.                                        |
# | `'seaborn-v0_8-pastel'`  | Estilo Seaborn con tonos pasteles.                                                       |
# | `'seaborn-v0_8-poster'`  | Estilo Seaborn diseñado para carteles.                                                  |
# | `'seaborn-v0_8-talk'`    | Estilo Seaborn adecuado para presentaciones.                                             |
# | `'seaborn-v0_8-ticks'`   | Estilo Seaborn con marcas de escala distintivas.                                        |
# | `'seaborn-v0_8-white'`   | Variante clara del estilo Seaborn.                                                       |
# | `'seaborn-v0_8-whitegrid'`| Variante clara con líneas de cuadrícula del estilo Seaborn.                             |
# | `'tableau-colorblind10'` | Paleta de colores de Tableau para personas con discapacidad visual.                     |

# %%
plt.style.use('seaborn-v0_8-deep')

# %% [markdown]
# ## Matlab

# %%
fig, ax = plt.subplots(figsize=(8,8))

ax.plot(x,x+1,'r--')
ax.plot(x,x+2,'b-')
ax.plot(x,x+3,'y.-')
ax.plot(x,x+4,'go:')

# %% [markdown]
# ## Pyplot
#
# ax.plot(atributos)
#
# | Atributo     | Uso                                                  |
# |--------------|------------------------------------------------------|
# | `linewidth`  | Grosor de la línea.                                 |
# | `color`      | Color de la línea. Puede ser nombre o código RGB.   |
# | `linestyle`  | Estilo de la línea ('-', ':', '--', etc.).           |
# | `marker`     | Marcador de puntos en la línea ('o', 's', 'x', etc.). |
# | `markersize` | Tamaño de los marcadores.                           |
# | `markeredgecolor` | Color del borde de los marcadores.           |
# | `markerfacecolor` | Color del relleno de los marcadores.        |
# | `alpha`      | Transparencia de la línea (entre 0 y 1).           |
# | `label`      | Etiqueta para la leyenda del gráfico.               |

# %%
fig, ax = plt.subplots(figsize=(8,8))

ax.plot(x,x+1,color = 'green', alpha=0.8, linewidth=5, linestyle='-',marker='o'
,markersize=10, markerfacecolor='#CCFFCC')
ax.plot(x,x+2,color = 'blue', linewidth=8 , linestyle='--',marker='8')
ax.plot(x,x+3,color = '#66FF66', linewidth=3 ,linestyle='dashed',marker='v')
ax.plot(x,x+4,color = '#CCFFCC', linewidth=2 ,linestyle=':',marker='P')
